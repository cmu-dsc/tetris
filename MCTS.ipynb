# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-05e945ed-39df-4bba-8585-c4d5cc961398" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-05e945ed-39df-4bba-8585-c4d5cc961398">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving app.py to app.py
# Saving cmu_112_graphics.py to cmu_112_graphics.py
# Saving gamestate.py to gamestate.py
# Saving mcts_gif.py to mcts_gif.py
# Saving modeling.py to modeling.py
# Saving piece.py to piece.py
# Saving pieces.py to pieces.py
# Saving playfield.py to playfield.py
# Saving playfield_controller.py to playfield_controller.py
# Saving test_MCTS.py to test_MCTS.py
# Saving train_MCTS.py to train_MCTS.py
# ...

# %%
# !python3 train_MCTS.py
# Out:
# 2020-10-17 11:44:05.925102: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 0 game, 0.000000 rewards, 210 num of steps
# Traceback (most recent call last):
#   File "train_MCTS.py", line 103, in <module>
#     data, _, reward = tree.generate_a_game(num_iter=50, max_steps=500, stats_writer=(writer, game))
#   File "/content/modeling.py", line 62, in generate_a_game
#   File "/content/modeling.py", line 118, in make_move_remove_and_dump_unused_branch
#     data += dump_branch(self.root.child_nodes[action], deepcopy(pc))
#   File "/content/modeling.py", line 103, in dump_branch
#     data += dump_branch(node.child_nodes[action], new_pc)
#   File "/content/modeling.py", line 102, in dump_branch
#     new_pc.update()
#   File "/content/playfield_controller.py", line 177, in update
#     self._active_piece.coords[1] - 1)):
#   File "/content/playfield.py", line 39, in is_legal_move
# ...
